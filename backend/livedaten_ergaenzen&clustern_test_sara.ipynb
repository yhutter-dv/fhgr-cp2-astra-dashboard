# %% [markdown]
# # Live Daten einlesen

# %%
import pandas as pd
import json

json_file_path = "./data/msr.json"

# read JSON
with open(json_file_path, 'r') as file:
    data = json.load(file)

# create an empty list
df_list = []

# get out all sensorMeasurements data and adds it to the rest of the detector measurements
for entry in data['detector_measurements']:
    measurements_data = entry['sensorMeasurements']
    entry.pop('sensorMeasurements')  # delete 'sensorMeasurements'(we only need each measurement)
    for measurement in measurements_data:
        entry.update(measurement)  # add details of sensorMeasurements entry
        df_list.append(entry.copy())  # append copy of entry to list

# create DataFrame
df = pd.DataFrame(df_list)

# show DataFrame
df
# Out:
#               id                         time        value  hasError  \
# 0     CH:0542.05  2023-12-02T12:37:00.000000Z     0.000000      True
# 1     CH:0026.03  2023-12-02T12:37:00.000000Z  1320.000000     False
# 2     CH:0026.03  2023-12-02T12:37:00.000000Z    96.699997     False
# 3     CH:0026.03  2023-12-02T12:37:00.000000Z     0.000000     False
# 4     CH:0026.03  2023-12-02T12:37:00.000000Z     0.000000     False
# ...          ...                          ...          ...       ...
# 6342  CH:0505.03  2023-12-02T12:37:00.000000Z     0.000000     False
# 6343  CH:0505.02  2023-12-02T12:37:00.000000Z   900.000000     False
# 6344  CH:0505.02  2023-12-02T12:37:00.000000Z   115.300003     False
# 6345  CH:0505.02  2023-12-02T12:37:00.000000Z     0.000000     False
# 6346  CH:0505.02  2023-12-02T12:37:00.000000Z     0.000000     False
#
#      errorReason  index          kind  numberOfInputValuesUsed
# 0     VD_OFFLINE      0                                    NaN
# 1                    11   trafficFlow                      NaN
# 2                    12  trafficSpeed                     22.0
# 3                    21   trafficFlow                     22.0
# 4                     1   trafficFlow                     22.0
# ...          ...    ...           ...                      ...
# 6342                  1   trafficFlow                     22.0
# 6343                 11   trafficFlow                      NaN
# 6344                 12  trafficSpeed                     15.0
# 6345                 21   trafficFlow                     15.0
# 6346                  1   trafficFlow                     15.0
#
# [6347 rows x 8 columns]

# %%
# make sure that time is a datetime
df['time'] = pd.to_datetime(df['time'])
df
# Out:
#               id                      time        value  hasError errorReason  \
# 0     CH:0542.05 2023-12-02 12:37:00+00:00     0.000000      True  VD_OFFLINE
# 1     CH:0026.03 2023-12-02 12:37:00+00:00  1320.000000     False
# 2     CH:0026.03 2023-12-02 12:37:00+00:00    96.699997     False
# 3     CH:0026.03 2023-12-02 12:37:00+00:00     0.000000     False
# 4     CH:0026.03 2023-12-02 12:37:00+00:00     0.000000     False
# ...          ...                       ...          ...       ...         ...
# 6342  CH:0505.03 2023-12-02 12:37:00+00:00     0.000000     False
# 6343  CH:0505.02 2023-12-02 12:37:00+00:00   900.000000     False
# 6344  CH:0505.02 2023-12-02 12:37:00+00:00   115.300003     False
# 6345  CH:0505.02 2023-12-02 12:37:00+00:00     0.000000     False
# 6346  CH:0505.02 2023-12-02 12:37:00+00:00     0.000000     False
#
#       index          kind  numberOfInputValuesUsed
# 0         0                                    NaN
# 1        11   trafficFlow                      NaN
# 2        12  trafficSpeed                     22.0
# 3        21   trafficFlow                     22.0
# 4         1   trafficFlow                     22.0
# ...     ...           ...                      ...
# 6342      1   trafficFlow                     22.0
# 6343     11   trafficFlow                      NaN
# 6344     12  trafficSpeed                     15.0
# 6345     21   trafficFlow                     15.0
# 6346      1   trafficFlow                     15.0
#
# [6347 rows x 8 columns]

# %%
# index mapping to vehicle type

#sk: Vehicle Type würde ich nicht in die Live Daten integrieren, sondern eine im Filter hinterlegen: wenn "Lorry" ausgewählt ist, dann nimm alle Zeilen mit index 21 und index 22.. etc.

# %%
# add canton

# get measurement_station id
df['id_measurement_station'] = df['id'].str.split('.').str[0]

# read mst data
json_file_path = "./data/mst.json"
with open(json_file_path, 'r') as file:
    json_data = json.load(file)

# Create mapping
canton_mapping = {entry['id']: entry['canton'] for entry in json_data}
eastLv95_mapping = {entry['id']: entry['eastLv95'] for entry in json_data}
northLv95_mapping = {entry['id']: entry['northLv95'] for entry in json_data}

# Map 'canton' values to the DataFrame
df['canton'] = df['id_measurement_station'].map(canton_mapping)

df['eastLv95'] = df['id_measurement_station'].map(eastLv95_mapping)
df['eastLv95'] = df['eastLv95'].astype(float)

df['northLv95'] = df['id_measurement_station'].map(northLv95_mapping )
df['northLv95'] = df['northLv95'].astype(float)

# Display the updated DataFrame
df
# Out:
#               id                      time        value  hasError errorReason  \
# 0     CH:0542.05 2023-12-02 12:37:00+00:00     0.000000      True  VD_OFFLINE
# 1     CH:0026.03 2023-12-02 12:37:00+00:00  1320.000000     False
# 2     CH:0026.03 2023-12-02 12:37:00+00:00    96.699997     False
# 3     CH:0026.03 2023-12-02 12:37:00+00:00     0.000000     False
# 4     CH:0026.03 2023-12-02 12:37:00+00:00     0.000000     False
# ...          ...                       ...          ...       ...         ...
# 6342  CH:0505.03 2023-12-02 12:37:00+00:00     0.000000     False
# 6343  CH:0505.02 2023-12-02 12:37:00+00:00   900.000000     False
# 6344  CH:0505.02 2023-12-02 12:37:00+00:00   115.300003     False
# 6345  CH:0505.02 2023-12-02 12:37:00+00:00     0.000000     False
# 6346  CH:0505.02 2023-12-02 12:37:00+00:00     0.000000     False
#
#       index          kind  numberOfInputValuesUsed id_measurement_station  \
# 0         0                                    NaN                CH:0542
# 1        11   trafficFlow                      NaN                CH:0026
# 2        12  trafficSpeed                     22.0                CH:0026
# 3        21   trafficFlow                     22.0                CH:0026
# 4         1   trafficFlow                     22.0                CH:0026
# ...     ...           ...                      ...                    ...
# 6342      1   trafficFlow                     22.0                CH:0505
# 6343     11   trafficFlow                      NaN                CH:0505
# 6344     12  trafficSpeed                     15.0                CH:0505
# 6345     21   trafficFlow                     15.0                CH:0505
# 6346      1   trafficFlow                     15.0                CH:0505
#
#      canton   eastLv95  northLv95
# 0        AG  2668970.0  1254246.0
# 1        LU  2666381.0  1205794.0
# 2        LU  2666381.0  1205794.0
# 3        LU  2666381.0  1205794.0
# 4        LU  2666381.0  1205794.0
# ...     ...        ...        ...
# 6342     VD  2507348.0  1141026.0
# 6343     VD  2507348.0  1141026.0
# 6344     VD  2507348.0  1141026.0
# 6345     VD  2507348.0  1141026.0
# 6346     VD  2507348.0  1141026.0
#
# [6347 rows x 12 columns]

# %% [markdown]
# # Clusterings - a try

# %%
# tranform Lv95 to WGS84
from pyproj import Proj, transform

lv95 = Proj(init='epsg:2056')  # Lv95
wgs84 = Proj(init='epsg:4326')  # WGS84
df['lon'], df['lat'] = transform(lv95, wgs84, df['eastLv95'].values, df['northLv95'].values)
# Out:
# C:\Users\sarak\AppData\Local\Programs\Python\fhgr-cp2-astra-dashboard\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# C:\Users\sarak\AppData\Local\Programs\Python\fhgr-cp2-astra-dashboard\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# C:\Users\sarak\AppData\Local\Temp\ipykernel_15376\1072553721.py:6: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   df['lon'], df['lat'] = transform(lv95, wgs84, df['eastLv95'].values, df['northLv95'].values)

# %%
# I want to draw the dots just once. This is not a final solution (only for displaying the different clustrings)
df_short = df.drop_duplicates(subset='id_measurement_station')
df_short
# Out:
#               id                      time   value  hasError errorReason  \
# 0     CH:0542.05 2023-12-02 12:37:00+00:00     0.0      True  VD_OFFLINE
# 1     CH:0026.03 2023-12-02 12:37:00+00:00  1320.0     False
# 5     CH:0301.03 2023-12-02 12:37:00+00:00  1440.0     False
# 35    CH:0668.01 2023-12-02 12:37:00+00:00   180.0     False
# 51    CH:0141.01 2023-12-02 12:37:00+00:00   180.0     False
# ...          ...                       ...     ...       ...         ...
# 6292  CH:0270.05 2023-12-02 12:37:00+00:00     0.0      True  VD_OFFLINE
# 6294  CH:0363.01 2023-12-02 12:37:00+00:00   180.0     False
# 6301  CH:0505.04 2023-12-02 12:37:00+00:00  1080.0     False
# 6309  CH:0318.04 2023-12-02 12:37:00+00:00   540.0     False
# 6317  CH:0748.01 2023-12-02 12:37:00+00:00   120.0     False
#
#       index         kind  numberOfInputValuesUsed id_measurement_station  \
# 0         0                                   NaN                CH:0542
# 1        11  trafficFlow                      NaN                CH:0026
# 5        11  trafficFlow                      NaN                CH:0301
# 35       11  trafficFlow                      NaN                CH:0668
# 51       11  trafficFlow                      NaN                CH:0141
# ...     ...          ...                      ...                    ...
# 6292      0                                   NaN                CH:0270
# 6294     11  trafficFlow                      NaN                CH:0363
# 6301     11  trafficFlow                      NaN                CH:0505
# 6309     11  trafficFlow                      NaN                CH:0318
# 6317     11  trafficFlow                      NaN                CH:0748
#
#      canton   eastLv95  northLv95       lon        lat
# 0        AG  2668970.0  1254246.0  8.352890  47.435399
# 1        LU  2666381.0  1205794.0  8.311432  46.999884
# 5        ZH  2674350.0  1246800.0  8.422963  47.367848
# 35       VS  2561300.0  1121840.0  6.936855  46.246876
# 51       TG  2731748.0  1267622.0  9.188821  47.546099
# ...     ...        ...        ...       ...        ...
# 6292     ZH  2685589.0  1251824.0  8.572700  47.411666
# 6294     BE  2624175.0  1232976.0  7.757955  47.247258
# 6301     VD  2507348.0  1141026.0  6.233557  46.414169
# 6309     SG  2751449.0  1212623.0  9.431870  47.047327
# 6317     BE  2595045.0  1161365.0  7.373968  46.603527
#
# [465 rows x 14 columns]

# %% [markdown]
# ## canton

# %%
import folium
from folium.plugins import MarkerCluster
from folium import FeatureGroup, LayerControl
from IPython.display import display

center_lat = df_short['lat'].mean()
center_lon = df_short['lon'].mean()

m = folium.Map(location=[center_lat, center_lon], zoom_start=8)

# group markers
# marker_cluster = MarkerCluster().add_to(m)
layer_control = LayerControl().add_to(m)

for index, row in df_short.iterrows():

    folium.CircleMarker(
        location= [row['lat'], row['lon']],
        radius=4,
        color='grey',
        fill=True,
        fill_color='grey',
        fill_opacity=0.4,
        popup=row['canton']
    ).add_to(m)
m.save('map_canton.html')
display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_05e8270e4579cdb471bf29e4d9e035ca {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_05e8270e4579cdb471bf29e4d9e035ca&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_05e8270e4579cdb471bf29e4d9e035ca = L.map(
#                 &quot;map_05e8270e4579cdb471bf29e4d9e035ca&quot;,
#                 {
#                     center: [47.01680037078719, 8.130513695596692],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_166611b6b7f8bc9ae64c93957e0483a9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_166611b6b7f8bc9ae64c93957e0483a9.addTo(map_05e8270e4579cdb471bf29e4d9e035ca);
#
#
#             var layer_control_52671d9aba5bae0733ee77b23c91ba5d_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_166611b6b7f8bc9ae64c93957e0483a9,
#                 },
#                 overlays :  {
#                 },
#             };
#             let layer_control_52671d9aba5bae0733ee77b23c91ba5d = L.control.layers(
#                 layer_control_52671d9aba5bae0733ee77b23c91ba5d_layers.base_layers,
#                 layer_control_52671d9aba5bae0733ee77b23c91ba5d_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_05e8270e4579cdb471bf29e4d9e035ca);
#
#
#
#             var circle_marker_b5138c7f3ceeaaf128c97cc019444e18 = L.circleMarker(
#                 [47.4353988261475, 8.352890458792674],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;grey&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;grey&quot;, &quot;fillOpacity&quot;: 0.4, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_05e8270e4579cdb471bf29e4d9e035ca);
#
#
#         var popup_15e388a4effc0d67ac2d9ee2a85e1efc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b767b7b36278b9613e28a07c8dc3a509 = $(`&lt;div id=&quot;html_b767b7b36278b9613e28a07c8dc3a509&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;AG&lt;/div&gt;`)[0];
#                 popup_15e388a4effc0d67ac2d9ee2a85e1efc.setContent(html_b767b7b36278b9613e28a07c8dc3a509);
#
#
#
#         circle_marker_b5138c7f3ceeaaf128c97cc019444e18.bindPopup(popup_15e388a4effc0d67ac2d9ee2a85e1efc)
#         ;
#
#
#
#
#             var circle_marker_cfc37c1f4b78d9aa3b59e8d6178c43ad = L.circleMarker(
#                 [46.99988425043461, 8.311431721546521],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;grey&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;grey&quot;, &quot;fillOpacity&quot;: 0.4, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_05e8270e4579cdb471bf29e4d9e035ca);
#
#
#         var popup_5b1c3dfad99f9aa4d34e1ca6c1751969 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_23b0e23a073ce77d7916168f5f4e56bd = $(`&lt;div id=&quot;html_23b0e23a073ce77d7916168f5f4e56bd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;LU&lt;/div&gt;`)[0];
#                 popup_5b1c3dfad99f9aa4d34e1ca6c1751969.setContent(html_23b0e23a073ce77d7916168f5f4e56bd);
#
#
#
#         circle_marker_cfc37c1f4b78d9aa3b59e8d6178c43ad.bindPopup(popup_5b1c3dfad99f9aa4d34e1ca6c1751969)
#         ;
#
#
#
#
#             var circle_marker_e64f703df4c67897c35bdf1b372d2be4 = L.circleMarker(
#                 [47.36784776063782, 8.422962584463162],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;grey&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;grey&quot;, &quot;fillOpacity&quot;: 0.4, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_05e8270e4579cdb471bf29e4d9e035ca);
#
#
#         var popup_ef2e87a16846d5475951f724602f8d50 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4070b76f3f109c89058bf19b9a65a969 = $(`&lt;div id=&q

# %% [markdown]
# ## k-means

# %%
from sklearn.cluster import KMeans


desired_number_of_clusters = 13
kmeans = KMeans(n_clusters=desired_number_of_clusters)
df_short['cluster_kmeans'] = kmeans.fit_predict(df_short[['eastLv95', 'northLv95']])
# Out:
# C:\Users\sarak\AppData\Local\Programs\Python\fhgr-cp2-astra-dashboard\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\sarak\AppData\Local\Temp\ipykernel_15376\1534044761.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_short['cluster_kmeans'] = kmeans.fit_predict(df_short[['eastLv95', 'northLv95']])

# %%
center_lat = df_short['lat'].mean()
center_lon = df_short['lon'].mean()

m = folium.Map(location=[center_lat, center_lon], zoom_start=8)

# group markers
# marker_cluster = MarkerCluster().add_to(m)
layer_control = LayerControl().add_to(m)

#add colors
colors_catalog = {
    1: 'darkblue', 2:'blue', 3: 'darkred',4:  'orange', 5: 'purple', 6: 'gray', 7: 'cadetblue',8: 'lightgreen',9: 'darkgreen', 10:'black',11: 'pink',12:'white', 0:'red'
}

for index, row in df_short.iterrows():
    color = colors_catalog.get(row['cluster_kmeans'], '#808080')

    folium.CircleMarker(
        location= [row['lat'], row['lon']],
        radius=4,
        color=color,
        fill=True,
        fill_color=color,
        fill_opacity=1,
        popup=row['cluster_kmeans']
    ).add_to(m)
m.save('map_k-means.html')
display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dee0fdd74a194443ba4405b0ee1aaafc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dee0fdd74a194443ba4405b0ee1aaafc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dee0fdd74a194443ba4405b0ee1aaafc = L.map(
#                 &quot;map_dee0fdd74a194443ba4405b0ee1aaafc&quot;,
#                 {
#                     center: [47.01680037078719, 8.130513695596692],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c0d75d6dd91490c349d29054b9a0b1ee = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c0d75d6dd91490c349d29054b9a0b1ee.addTo(map_dee0fdd74a194443ba4405b0ee1aaafc);
#
#
#             var layer_control_5887083ba9d0567f8b6d893d74ebd0b6_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_c0d75d6dd91490c349d29054b9a0b1ee,
#                 },
#                 overlays :  {
#                 },
#             };
#             let layer_control_5887083ba9d0567f8b6d893d74ebd0b6 = L.control.layers(
#                 layer_control_5887083ba9d0567f8b6d893d74ebd0b6_layers.base_layers,
#                 layer_control_5887083ba9d0567f8b6d893d74ebd0b6_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_dee0fdd74a194443ba4405b0ee1aaafc);
#
#
#
#             var circle_marker_04a9af0d94874b9d81910fff3d6f4756 = L.circleMarker(
#                 [47.4353988261475, 8.352890458792674],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_dee0fdd74a194443ba4405b0ee1aaafc);
#
#
#         var popup_f31780c77549d07f2a105f8d9b02ef2e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5a3166885cad1d39083a12f70c16e014 = $(`&lt;div id=&quot;html_5a3166885cad1d39083a12f70c16e014&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;10&lt;/div&gt;`)[0];
#                 popup_f31780c77549d07f2a105f8d9b02ef2e.setContent(html_5a3166885cad1d39083a12f70c16e014);
#
#
#
#         circle_marker_04a9af0d94874b9d81910fff3d6f4756.bindPopup(popup_f31780c77549d07f2a105f8d9b02ef2e)
#         ;
#
#
#
#
#             var circle_marker_db55d01bda1927c4e2b3285dd3aefb6e = L.circleMarker(
#                 [46.99988425043461, 8.311431721546521],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;gray&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;gray&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_dee0fdd74a194443ba4405b0ee1aaafc);
#
#
#         var popup_649153d17d61723be29f039a1e8208cd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0c6f4ec30b1cb1ddebef13e509cbf33b = $(`&lt;div id=&quot;html_0c6f4ec30b1cb1ddebef13e509cbf33b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;6&lt;/div&gt;`)[0];
#                 popup_649153d17d61723be29f039a1e8208cd.setContent(html_0c6f4ec30b1cb1ddebef13e509cbf33b);
#
#
#
#         circle_marker_db55d01bda1927c4e2b3285dd3aefb6e.bindPopup(popup_649153d17d61723be29f039a1e8208cd)
#         ;
#
#
#
#
#             var circle_marker_38dd1987078de62e159f325add12ef27 = L.circleMarker(
#                 [47.36784776063782, 8.422962584463162],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_dee0fdd74a194443ba4405b0ee1aaafc);
#
#
#         var popup_1bdba7d48b23a2a2090f5b5496173812 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2bc3b01e76f3aedb04449f121b3351b9 = $(`&lt;div id=&quot
